# %% [markdown]
# # Python Practice Sandbox
# Run the cell below to verify your libraries installed correctly!

# %%
import pandas as pd
import numpy as np

print("Codespace is ready!")
print(f"Pandas version: {pd.__version__}")
